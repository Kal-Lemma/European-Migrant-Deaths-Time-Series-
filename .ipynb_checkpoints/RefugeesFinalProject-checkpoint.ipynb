# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from matplotlib.pylab import rcParams
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
warnings
import itertools
plt.style.use('ggplot')

# %%
RefugeesDF = pd.read_csv('refugeesAndMigrants.csv')
RefugeesDF
#01/01/93 shown three times, Happens with multiple dates with different amount of occurance depending on  
#The number of locations where bodies were found on that date, 3 different locations were reported for 01/01/93
#Have to deal with last 5 rows: 4 with the '1993' dates and the 1 with the NaN values 
#Possibly take out the only '1993' rows, but add their 6 deaths to '01/01/93' (first_date after)
#Orginal DF with 3,931
# Out:
#      found dead  number                 name, gender, age    region of origin  \
# 0      05/05/18     4.0                      N.N. (1 man)              Africa
# 1      30/04/18     2.0                      N.N. (2 men)             unknown
# 2      30/04/18     1.0                      N.N. (woman)             unknown
# 3      30/04/18     6.0              N.N. (1 baby; 5 men)             unknown
# 4      30/04/18     1.0                        N.N. (man)             Algeria
# 5      29/04/18    19.0                      N.N. (1 man)              Africa
# 6      25/04/18    17.0                              N.N.  Sub-Saharan Africa
# 7      22/04/18    11.0              N.N. (1 boy; 10 men)             unknown
# 8      20/04/18     1.0              N.N. (boy, 6 months)             Eritrea
# 9      20/04/18     1.0          Snaid Tadese (woman, 19)             Eritrea
# 10     20/04/18     1.0                    N.N. (man, 30)             unknown
# 11     19/04/18     2.0                              N.N.             unknown
# 12     14/04/18     1.0                        N.N. (man)             unknown
# 13     13/04/18     1.0                        N.N. (man)             unknown
# 14     10/04/18     1.0                        N.N. (man)             unknown
# 15     09/04/18     1.0                        N.N. (man)             unknown
# 16     09/04/18    36.0                              N.N.             unknown
# 17     06/04/18     1.0             Omar "Susi" (boy, 16)             Maghreb
# 18     06/04/18     1.0                      N.N. (woman)             unknown
# 19     02/04/18     1.0                        N.N. (man)             unknown
# 20     01/04/18    11.0                      N.N. (1 man)             unknown
# 21     01/04/18     1.0                        N.N. (man)             unknown
# 22     01/04/18     1.0                        N.N. (man)             unknown
# 23     31/03/18     1.0                              N.N.             unknown
# 24     30/03/18    17.0                              N.N.             unknown
# 25     29/03/18     7.0                      N.N. (7 men)             unknown
# 26     28/03/18     1.0                    N.N. (boy, 16)             Eritrea
# 27     24/03/18     1.0                      N.N. (woman)             unknown
# 28     22/03/18     1.0                    N.N. (man, 22)             Algeria
# 29     20/03/18     1.0                        N.N. (man)             unknown
# ...         ...     ...                               ...                 ...
# 3902   23/07/93     1.0      Nazmieh Chahrour (woman, 23)           Palestine
# 3903   17/06/93     1.0             Abdi Atalan (man, 41)           Kurdistan
# 3904   10/06/93     1.0                        N.N. (man)          Mozambique
# 3905   26/05/93     1.0                              N.N.             Eritrea
# 3906   26/05/93     1.0                              N.N.             Eritrea
# 3907   26/05/93     1.0                              N.N.             Eritrea
# 3908   06/05/93     1.0    Miroslawa Kolodziejska (w, 59)              Poland
# 3909   01/05/93     1.0     Yilma Wondwossen B. (man, 31)            Ethiopia
# 3910   23/04/93     1.0                    N.N. (man, 25)             Senegal
# 3911   07/04/93     1.0                              N.N.               Zaire
# 3909  drowned himself in Teltow Canal in Berlin (DE)...
# 3910  suicide, hanged himself in police cell in Eisl...
# 3911  shot point blank during interrogation at polic...
# 3912  hit by train in Balerna (CH) Swiss Alps while ...
# 3913     jumped out window of refugee centre in Germany
# 3914  hit by train in Coldrerio (CH) in the Swiss Al...
# 3915  suicide, set fire to himself at immigration of...
# 3916    suicide, at penal institution in Dinslaken (DE)
# 3917     suffocated in bus compartment near Vienna (AT)
# 3918     suffocated in bus compartment near Vienna (AT)
# 3919     suffocated in bus compartment near Vienna (AT)
# 3920     suffocated in bus compartment near Vienna (AT)
# 3921  shot in front of police station in Saxony-Anha...
# 3922  died in hospital in Munich (DE) after jumping ...
# 3923  suicide, in Munich (DE) after being told he wo...
# 3924  died of exhaustion/exposure in rail container ...
# 3925  drowned after boat collided with a cliff and c...
# 3926  died in arson attack on refugee camp in Baden-...
# 3927  died after deportation from Austria to Evin Pr...
# 3928  drowned in the Oder River while trying to cros...
# 3929     body found at the German-Austrian-Czech border
# 3930  suicide, found hanged in detention centre 5 da...
# 3931                                                NaN
#
#                                         source country of incident
# 0                    AFP/IOM Libya/BangkokPost               Libya
# 1                                    IOM Libya               Libya
# 2                                    IOM Libya               Libya
# 3                                    IOM Libya               Libya
# 4                 IOM Slovenia/TotSloveniaNews             unknown
# 5       ObsAlgerie/Caminando/EFE/Réf/QUOTI/IOM             Algeria
# 6          ElDiario/Caminando/SalvaM/EuroPress             unknown
# 7                MEE/Reu./IOM Libya/JapanTimes               Libya
# 8                       Berliner Ztg/FR-th/OTZ             Germany
# 9                       Berliner Ztg/FR-th/OTZ             Germany
# 10                       AP/NYTimes/MailOnline              Greece
# 11                        HurriyetDN/PrensaLat              Turkey
# 12                 FaroCeuta/APDHA/CeutaTV/IOM               Spain
# 13                 FaroCeuta/APDHA/IOM/CeutaTV               Spain
# 14                            IOM Slovenia/AFP            Slovenia
# 15                           DELO/IOM Slovenia            Slovenia
# 16                 EFE/Caminando/El Diario/IOM             Morocco
# 17       El Faro de Ceuta/Ceuta Actualidad/IOM               Spain
# 18              Diario de Cádiz/IOM/EPress/EFE               Spain
# 19                   Liberté/Ouest Tribune/IOM             Algeria
# 20    Watch TheMed/IOM Spain/SalvaM/HinduTimes             Morocco
# 21                           Réf/DK/OuestT/IOM             Algeria
# 22                                EFE/IOM/YABI             Morocco
# 23                           Réf/DK/OuestT/IOM             Algeria
# 24                                 Reu./LV/IOM              Turkey
# 25                               Caminando/IOM             unknown
# 26                 CMS/Parisien/VoixDuNord/IOM              France
# 27                              CDS/FrSoir/IOM               Italy
# 28                                         CMS             Belgium
# 29                                   IOM Libya               Libya
# ...                                        ...                 ...
# 3902                  CARF/AR InfoNetw/taz/ZAG             Germany
# 3903                          CARF/Konkret/ZAG             Germany
# 3904                                       ZAG             Germany
# 3905                                  CARF/ZAG             Germany
# 3906                                  CARF/ZAG             Germany
# 3907                                  CARF/ZAG             Germany
# 3908               Wib/FR-NieSa/FR/ProAsyl/ZAG             Germany
# 3909                           taz/ProAsyl/ZAG             Germany
# 3910                              IRR/CARF/ZAG             Germany
# 3911                              Le Monde/MNS              France
# 3912                                    TA/NZZ         Switzerland
# 3913                                       ARI             unknown
# 3914                                TA/DAZ/NZZ         Switzerland
# 3915                                       IRR               Wales
# 3916                          WIB/FR-NieSa/ZAG             Germany
# 3917             AsylkoordinationÖsterreich/SP             Austria
# 3918             AsylkoordinationÖsterreich/SP             Austria
# 3919             AsylkoordinationÖsterreich/SP             Austria
# 3920             AsylkoordinationÖsterreich/SP             Austria
# 3921                        taz/Konkret/jW/ZAG             Germany
# 3922                                   ARI/ZAG             Germany
# 3923                          IRR/CARF/ESG/ZAG             Germany
# 3924                 NeueVorarlbergerTageszeit             Austria
# 3925                                CDS/MNS/TL             unknown
# 3926                                       ZAG             Germany
# 3927                AsylkoordinationÖsterreich                Iran
# 3928                  Jelpke/German Government             unknown
# 3929                  Jelpke/German Government             unknown
# 3930                                      CARF             unknown
# 3931                                       NaN             unknown
#
# [3932 rows x 7 columns]

# %%
RefugeesDF.drop(RefugeesDF.tail(1).index, inplace = True)
#Took out Last 5 rows in dataframe (first 5 entries in the time-line)

# %%
RefugeesDF.set_value(3926,'number',7)
RefugeesDF
#Added 5 more deaths to 01/01/93 deaths to keep them in count
# Out:
#      found dead  number                 name, gender, age    region of origin  \
# 0      05/05/18     4.0                      N.N. (1 man)              Africa
# 1      30/04/18     2.0                      N.N. (2 men)             unknown
# 2      30/04/18     1.0                      N.N. (woman)             unknown
# 3      30/04/18     6.0              N.N. (1 baby; 5 men)             unknown
# 4      30/04/18     1.0                        N.N. (man)             Algeria
# 5      29/04/18    19.0                      N.N. (1 man)              Africa
# 6      25/04/18    17.0                              N.N.  Sub-Saharan Africa
# 7      22/04/18    11.0              N.N. (1 boy; 10 men)             unknown
# 8      20/04/18     1.0              N.N. (boy, 6 months)             Eritrea
# 9      20/04/18     1.0          Snaid Tadese (woman, 19)             Eritrea
# 10     20/04/18     1.0                    N.N. (man, 30)             unknown
# 11     19/04/18     2.0                              N.N.             unknown
# 12     14/04/18     1.0                        N.N. (man)             unknown
# 13     13/04/18     1.0                        N.N. (man)             unknown
# 14     10/04/18     1.0                        N.N. (man)             unknown
# 15     09/04/18     1.0                        N.N. (man)             unknown
# 16     09/04/18    36.0                              N.N.             unknown
# 17     06/04/18     1.0             Omar "Susi" (boy, 16)             Maghreb
# 18     06/04/18     1.0                      N.N. (woman)             unknown
# 19     02/04/18     1.0                        N.N. (man)             unknown
# 20     01/04/18    11.0                      N.N. (1 man)             unknown
# 21     01/04/18     1.0                        N.N. (man)             unknown
# 22     01/04/18     1.0                        N.N. (man)             unknown
# 23     31/03/18     1.0                              N.N.             unknown
# 24     30/03/18    17.0                              N.N.             unknown
# 25     29/03/18     7.0                      N.N. (7 men)             unknown
# 26     28/03/18     1.0                    N.N. (boy, 16)             Eritrea
# 27     24/03/18     1.0                      N.N. (woman)             unknown
# 28     22/03/18     1.0                    N.N. (man, 22)             Algeria
# 20    4 drowned after boat capsized between Tangier ...
# 21    presumed drowned, body found near Habibas Isla...
# 22    presumed drowned, body found off coast of Al H...
# 23    presumed drowned, body found west of Sbiaat be...
# 24    died in vehicle accident in province of Igdir ...
# 25    presumed drowned, unspecified location in the ...
# 26    died in hospital in Lille after jumping from t...
# 27    died of lack of access to medicines in hospita...
# 28    stowaway, got stuck between 2 vehicles at Zeeb...
# 29    presumed drowned, body found on shore of Tripo...
# ...                                                 ...
# 3901  died of brain damage after struggle with immig...
# 3902  suicide, in prison in Berlin (DE) after being ...
# 3903  shot by neo-Nazis in front of refugee hostel i...
# 3904  died after injuries sustained during a fire at...
# 3905  died in suspected fascist arson attack in Hepp...
# 3906  died in suspected fascist arson attack in Hepp...
# 3907  died in suspected fascist arson attack in Hepp...
# 3908  suffocated by border police when detained at F...
# 3909  drowned himself in Teltow Canal in Berlin (DE)...
# 3910  suicide, hanged himself in police cell in Eisl...
# 3911  shot point blank during interrogation at polic...
# 3912  hit by train in Balerna (CH) Swiss Alps while ...
# 3913     jumped out window of refugee centre in Germany
# 3914  hit by train in Coldrerio (CH) in the Swiss Al...
# 3915  suicide, set fire to himself at immigration of...
# 3916    suicide, at penal institution in Dinslaken (DE)
# 3917     suffocated in bus compartment near Vienna (AT)
# 3918     suffocated in bus compartment near Vienna (AT)
# 3919     suffocated in bus compartment near Vienna (AT)
# 3920     suffocated in bus compartment near Vienna (AT)
# 3921  shot in front of police station in Saxony-Anha...
# 3922  died in hospital in Munich (DE) after jumping ...
# 3923  suicide, in Munich (DE) after being told he wo...
# 3924  died of exhaustion/exposure in rail container ...
# 3925  drowned after boat collided with a cliff and c...
# 3926  died in arson attack on refugee camp in Baden-...
# 3927  died after deportation from Austria to Evin Pr...
# 3928  drowned in the Oder River while trying to cros...
# 3929     body found at the German-Austrian-Czech border
# 3930  suicide, found hanged in detention centre 5 da...
#
#                                         source country of incident
# 0                    AFP/IOM Libya/BangkokPost               Libya
# 1                                    IOM Libya               Libya
# 2                                    IOM Libya               Libya
# 3                                    IOM Libya               Libya
# 4                 IOM Slovenia/TotSloveniaNews             unknown
# 5       ObsAlgerie/Caminando/EFE/Réf/QUOTI/IOM             Algeria
# 6          ElDiario/Caminando/SalvaM/EuroPress             unknown
# 7                MEE/Reu./IOM Libya/JapanTimes               Libya
# 8                       Berliner Ztg/FR-th/OTZ             Germany
# 9                       Berliner Ztg/FR-th/OTZ             Germany
# 10                       AP/NYTimes/MailOnline              Greece
# 11                        HurriyetDN/PrensaLat              Turkey
# 12                 FaroCeuta/APDHA/CeutaTV/IOM               Spain
# 13                 FaroCeuta/APDHA/IOM/CeutaTV               Spain
# 14                            IOM Slovenia/AFP            Slovenia
# 15                           DELO/IOM Slovenia            Slovenia
# 16                 EFE/Caminando/El Diario/IOM             Morocco
# 17       El Faro de Ceuta/Ceuta Actualidad/IOM               Spain
# 18              Diario de Cádiz/IOM/EPress/EFE               Spain
# 19                   Liberté/Ouest Tribune/IOM             Algeria
# 20    Watch TheMed/IOM Spain/SalvaM/HinduTimes             Morocco
# 21                           Réf/DK/OuestT/IOM             Algeria
# 22                                EFE/IOM/YABI             Morocco
# 23                           Réf/DK/OuestT/IOM             Algeria
# 24                                 Reu./LV/IOM              Turkey
# 25                               Caminando/IOM             unknown
# 26                 CMS/Parisien/VoixDuNord/IOM              France
# 27                              CDS/FrSoir/IOM               Italy
# 28                                         CMS             Belgium
# 29                                   IOM Libya               Libya
# ...                                        ...                 ...
# 3901    IRR/MNS/Times/Independent/ST/NCADC/BBC               Wales
# 3902                  CARF/AR InfoNetw/taz/ZAG             Germany
# 3903                          CARF/Konkret/ZAG             Germany
# 3904                                       ZAG             Germany
# 3905                                  CARF/ZAG             Germany
# 3906                                  CARF/ZAG             Germany
# 3907                                  CARF/ZAG             Germany
# 3908               Wib/FR-NieSa/FR/ProAsyl/ZAG             Germany
# 3909                           taz/ProAsyl/ZAG             Germany
# 3910                              IRR/CARF/ZAG             Germany
# 3911                              Le Monde/MNS              France
# 3912                                    TA/NZZ         Switzerland
# 3913                                       ARI             unknown
# 3914                                TA/DAZ/NZZ         Switzerland
# 3915                                       IRR               Wales
# 3916                          WIB/FR-NieSa/ZAG             Germany
# 3917             AsylkoordinationÖsterreich/SP             Austria
# 3918             AsylkoordinationÖsterreich/SP             Austria
# 3919             AsylkoordinationÖsterreich/SP             Austria
# 3920             AsylkoordinationÖsterreich/SP             Austria
# 3921                        taz/Konkret/jW/ZAG             Germany
# 3922                                   ARI/ZAG             Germany
# 3923                          IRR/CARF/ESG/ZAG             Germany
# 3924                 NeueVorarlbergerTageszeit             Austria
# 3925                                CDS/MNS/TL             unknown
# 3926                                       ZAG             Germany
# 3927                AsylkoordinationÖsterreich                Iran
# 3928                  Jelpke/German Government             unknown
# 3929                  Jelpke/German Government             unknown
# 3930                                      CARF             unknown
#
# [3931 rows x 7 columns]

# %%
RefugeesDF.isnull().sum()
# Out:
# found dead             0
# number                 0
# name, gender, age      0
# region of origin       0
# cause of death         0
# source                 0
# country of incident    0
# dtype: int64

# %%
#New DF for focusing on Time Series
TS_Refugees_df = RefugeesDF[["found dead", "number"]]
TS_Refugees_df
#3898 has 'Sep 93' as it's date, need to check if there are others like that and fix them
#Begins with 3,926 rows
# Out:
#      found dead  number
# 0      05/05/18     4.0
# 1      30/04/18     2.0
# 2      30/04/18     1.0
# 3      30/04/18     6.0
# 4      30/04/18     1.0
# 5      29/04/18    19.0
# 6      25/04/18    17.0
# 7      22/04/18    11.0
# 8      20/04/18     1.0
# 9      20/04/18     1.0
# 10     20/04/18     1.0
# 11     19/04/18     2.0
# 12     14/04/18     1.0
# 13     13/04/18     1.0
# 14     10/04/18     1.0
# 15     09/04/18     1.0
# 16     09/04/18    36.0
# 17     06/04/18     1.0
# 18     06/04/18     1.0
# 19     02/04/18     1.0
# 20     01/04/18    11.0
# 21     01/04/18     1.0
# 22     01/04/18     1.0
# 23     31/03/18     1.0
# 24     30/03/18    17.0
# 25     29/03/18     7.0
MessedUpDF = TS_Refugees_df[TS_Refugees_df['found dead'].str.match('[A-Z][a-z]')]
Messy_Dates = MessedUpDF['found dead']
Messy_Dates
#Found all dates not in the right format, 455 rows to fix or delete
#Can Possibly search for each months string (EX: 'Jan/', think need to include space) and replace it with '01/01/'
# Out:
# 141       Jan 18
# 142       Jan 18
# 193       Nov 17
# 194       Nov 17
# 195       Nov 17
# 196       Nov 17
# 213       Oct 17
# 214       Oct 17
# 258       Aug 17
# 259       Aug 17
# 281       Jul 17
# 314       Jun 17
# 345       May 17
# 346       May 17
# 347       May 17
# 348       May 17
# 409       Feb 17
# 439       Jan 17
# 450       Dec 16
# 492       Oct 16
# 499       Sep 16
# 568       Mar 16
# 569       Mar 16
# 570       Mar 16
# 571       Mar 16
# 603       Jan 16
# 626       Dec 15
# 627       Dec 15
# 628       Dec 15
# 629       Dec 15
#           ...
# 3646      Jun 96
# 3690      Jan 96
# 3703      Nov 95
# 3711      Oct 95
# 3712      Oct 95
# 3750      Jul 95
# 3751      Jul 95
# 3752      Jul 95
# 3763      Jun 95
# 3764      Jun 95
# 3765      Jun 95
# 3770      May 95
# 3784      Mar 95
# 3791      Feb 95
# 3792      Feb 95
# 3801      Jan 95
# 3802      Jan 95
# 3809      Dec 94
# 3812      Nov 94
# 3840      Aug 94
# 3853    Jun 1994
# 3859      May 94
# 3863      Apr 94
# 3864      Apr 94
# 3872    Feb 1994
# 3875      Jan 94
# 3876      Jan 94
# 3889      Dec 93
# 3895      Oct 93
# 3898      Sep 93
# Name: found dead, Length: 455, dtype: object

# %%
MessedUpDF['number'].sum()
#Saving 2,865 deaths to remain in our dataset
# Out:
# 2865.0

# %%
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Jan\s', value = '01/01/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Feb\s', value = '01/02/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Mar\s', value = '01/03/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Apr\s', value = '01/04/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='May\s', value = '01/05/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Jun\s', value = '01/06/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Jul\s', value = '01/07/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Aug\s', value = '01/08/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Sep\s', value = '01/09/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Oct\s', value = '01/10/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Nov\s', value = '01/11/', regex = True)
TS_Refugees_df = TS_Refugees_df.replace(to_replace ='Dec\s', value = '01/12/', regex = True)
TS_Refugees_df
#Fix for all the Messy Dates by just adding the months since the years were already in the cells
#Manage to keep all 455 death counts for those messy days
# Out:
#      found dead  number
# 0      05/05/18     4.0
# 1      30/04/18     2.0
# 2      30/04/18     1.0
# 3      30/04/18     6.0
# 4      30/04/18     1.0
# 5      29/04/18    19.0
# 6      25/04/18    17.0
# 7      22/04/18    11.0
# 8      20/04/18     1.0
# 9      20/04/18     1.0
# 10     20/04/18     1.0
# 11     19/04/18     2.0
# 12     14/04/18     1.0
# 13     13/04/18     1.0
# 14     10/04/18     1.0
# 15     09/04/18     1.0
# 16     09/04/18    36.0
# 17     06/04/18     1.0
# 18     06/04/18     1.0
# 19     02/04/18     1.0
# 20     01/04/18    11.0
# 21     01/04/18     1.0
# 22     01/04/18     1.0
# 23     31/03/18     1.0
# 24     30/03/18    17.0
# 25     29/03/18     7.0
# 26     28/03/18     1.0
# 27     24/03/18     1.0
# 01/01/17       1.0
# 01/01/18       3.0
# 01/01/93      19.0
# 01/01/94       5.0
# 01/01/95       3.0
# 01/01/96       1.0
# 01/01/97       8.0
# 01/01/99       9.0
# 01/02/00      16.0
# 01/02/01       4.0
# 01/02/02       5.0
# 01/02/03       6.0
# 01/02/04       1.0
# 01/02/05       2.0
# 01/02/06       3.0
# 01/02/07       1.0
# ...            ...
# 31/03/11      70.0
# 31/03/12      10.0
# 31/03/16       1.0
# 31/03/18       1.0
# 31/05/03      15.0
# 31/05/14       1.0
# 31/05/17      14.0
# 31/07/03      15.0
# 31/07/04       5.0
# 31/07/08      17.0
# 31/07/13      24.0
# 31/07/16       1.0
# 31/07/17       1.0
# 31/08/02       5.0
# 31/08/10       2.0
# 31/08/14     105.0
# 31/08/17      15.0
# 31/08/97       1.0
# 31/10/05       2.0
# 31/10/15       1.0
# 31/10/98       1.0
# 31/10/99       6.0
# 31/12/00       1.0
# 31/12/06      33.0
# 31/12/09      22.0
# 31/12/12       2.0
# 31/12/17      64.0
# 31/12/97       1.0
# 31/12/98      11.0
# 31/12/99      99.0
#
# [2407 rows x 1 columns]

# %%
#Finished cleaning up Dates format, summed up Same days so have Daily Counts for Deaths 
#Can now change into datetime format

# %%
DailyDeaths_TS_Refugees_df.index = pd.to_datetime(DailyDeaths_TS_Refugees_df.index, format='%d/%m/%y')
DailyDeaths_TS_Refugees_df.info()
#Changing the new 'found dead' index to Datetime type with proper format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2407 entries, 2000-01-01 to 1999-12-31
# Data columns (total 1 columns):
# number    2407 non-null float64
# dtypes: float64(1)
# memory usage: 37.6 KB

# %%
DailyDeaths_TS_Refugees_df.index
# Out:
# DatetimeIndex(['2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01',
#                '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01',
#                '2008-01-01', '2009-01-01',
#                ...
#                '1998-10-31', '1999-10-31', '2000-12-31', '2006-12-31',
#                '2009-12-31', '2012-12-31', '2017-12-31', '1997-12-31',
#                '1998-12-31', '1999-12-31'],
#               dtype='datetime64[ns]', name='found dead', length=2407, freq=None)

# %%
DailyDeaths_TS_Refugees_df
#Now Have 'Year-Month-Day' format, with datetime 'type' and set as the index for Daily Deaths
#2,407 rows = Days Total
# Out:
#             number
# found dead
# 2000-01-01     7.0
# 2001-01-01    32.0
# 2002-01-01    26.0
# 2003-01-01     8.0
# 2004-01-01     1.0
# 2005-01-01     1.0
# 2006-01-01     1.0
# 2007-01-01     4.0
# 2008-01-01    18.0
# 2009-01-01    13.0
# 2010-01-01     1.0
# 2012-01-01    38.0
# 2015-01-01    31.0
# 2016-01-01     3.0
# 2017-01-01     1.0
# 2018-01-01     3.0
# 1993-01-01    19.0
# 1994-01-01     5.0
# 1995-01-01     3.0
# 1996-01-01     1.0
# 1997-01-01     8.0
# 1999-01-01     9.0
# 2000-02-01    16.0
# 2001-02-01     4.0
# 2002-02-01     5.0
# 2003-02-01     6.0
# 2004-02-01     1.0
# 2005-02-01     2.0
# 2006-02-01     3.0
# 2007-02-01     1.0
# ...            ...
# 2011-03-31    70.0
# 2012-03-31    10.0
# 2016-03-31     1.0
# 2018-03-31     1.0
# 2003-05-31    15.0
# 2014-05-31     1.0
# 2017-05-31    14.0
# 2003-07-31    15.0
# 2004-07-31     5.0
# 2008-07-31    17.0
# 2013-07-31    24.0
# 2016-07-31     1.0
# 2017-07-31     1.0
# 2002-08-31     5.0
# 2010-08-31     2.0
# 2014-08-31   105.0
# 2017-08-31    15.0
# 1997-08-31     1.0
# 2005-10-31     2.0
# 2015-10-31     1.0
# 1998-10-31     1.0
# 1999-10-31     6.0
# 2000-12-31     1.0
# 2006-12-31    33.0
# 2009-12-31    22.0
# 2012-12-31     2.0
# 2017-12-31    64.0
# 1997-12-31     1.0
# 1998-12-31    11.0
# 1999-12-31    99.0
#
# [2407 rows x 1 columns]

# %%
MonthlyDeathsDF = DailyDeaths_TS_Refugees_df[:"2017"].groupby(pd.Grouper(freq = 'MS')).sum()
MonthlyDeathsDF
#300 Months from 1993-2017, excluding 2018 since doesn't have full dataset
# Out:
#             number
# found dead
# 1993-01-01    27.0
# 1993-02-01     0.0
# 1993-03-01     4.0
# 1993-04-01     4.0
# 1993-05-01     5.0
# 1993-06-01     2.0
# 1993-07-01     1.0
# 1993-08-01     3.0
# 1993-09-01     4.0
# 1993-10-01     3.0
# 1993-11-01     3.0
# 1993-12-01     5.0
# 1994-01-01     7.0
# 1994-02-01     8.0
# 1994-03-01     4.0
# 1994-04-01     5.0
# 1994-05-01    12.0
# 1994-06-01     7.0
# 1994-07-01     6.0
# 1994-08-01     8.0
# 1994-09-01    14.0
# 1994-10-01    21.0
# 1994-11-01    14.0
# 1994-12-01     6.0
# 1995-01-01    14.0
# 1995-02-01     8.0
# 1995-03-01    10.0
# 1995-04-01     5.0
# 1995-05-01     5.0
# 1995-06-01    13.0
# ...            ...
# 2015-07-01   128.0
# 2015-08-01   659.0
# 2015-09-01   259.0
# 2015-10-01   336.0
# 2015-11-01   182.0
# 2015-12-01   189.0
# 2016-01-01   210.0
# 2016-02-01    69.0
# 2016-03-01    59.0
# 2016-04-01  1053.0
# 2016-05-01  1178.0
# 2016-06-01   178.0
# 2016-07-01   144.0
# 2016-08-01    10.0
# 2016-09-01   227.0
# 2016-10-01   217.0
# 2016-11-01   629.0
# 2016-12-01    18.0
# 2017-01-01   343.0
# 2017-02-01   282.0
# 2017-03-01   414.0
# 2017-04-01   397.0
# 2017-05-01   696.0
# 2017-06-01   664.0
# 2017-07-01   155.0
# 2017-08-01   183.0
# 2017-09-01   173.0
# 2017-10-01   184.0
# 2017-11-01   310.0
# 2017-12-01   107.0
#
# [300 rows x 1 columns]

# %%
DailyDeaths_TS_Refugees_df.number.sum()
#34,028 = Total Deaths in our DataSet
# Out:
# 34028.0

# %%
DailyDeaths_TS_Refugees_df.isnull().sum()
#No NaN values
# Out:
# number    0
# dtype: int64

# %%
DailyDeaths_TS_Refugees_df.plot(figsize = (20,6))
plt.show()

# %%
DailyDeaths_TS_Refugees_df.plot(figsize = (20,6), style = ".b")
plt.show()

# %%
#Grouping Anually to Visualize yearly trends, with monthly values
months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
year_groups = DailyDeaths_TS_Refugees_df[:"2017"].groupby(pd.Grouper(freq = 'MS')).sum().groupby(pd.Grouper(freq = "YS"))
Annual_Deaths = pd.DataFrame()
for yr, group in year_groups:
    Annual_Deaths[yr.year] = group.values.ravel()
Annual_Deaths
Annual_Deaths.plot(figsize = (13,80), subplots=True, legend=True)
plt.xlabel("months")
plt.xticks(range(12), months)
plt.show()
#Frightening to watch how over the years, deaths continually increased, breaking maximums 6 times over 24 years
#Also shows increase in average amount of accounted (reported) deaths over the years 
#Looks like 1999 and 2000 almost mimic eachother
#Seems there are Significant increases during late 1996 with waves in 1997 being mimiced by the following years,
#Another Large Increase in 2006 With a new max of 400, with a similar trend but lower number for the next two years
#Large New Spike in Mar 2011 with new max of 800, Sept/Aug 2013 with 600, Sept 2014 was 800, April 2015 Max= 1250
#SPike starting Mar-May 2016
#Seems there are Significant decreases during 1993 and mostly all of 1994, and 1996 with both a rise at the end, 
#Also Decreases in Early 2006 till half way with a quick Significant increase starting May, same with May-Mar 2015-16
#Odd steady low count during Feb-May in 2002, also during Mar-July 2004, Jan-Jul 2010, Jul-2011 through Sept 2013 
#Steady High Death counts from Jan-Jul 2017

# %%
Annual_Deaths.plot(figsize = (15,5), subplots=False, legend=True)
plt.show()

# %%
Annual_Deaths.hist(figsize = (10,6))
plt.show()

# %%
# Generate a box and whiskers plot for temp_annual dataframe
Annual_Deaths.boxplot(figsize = (12,7))
plt.show()

# %%
year_matrix = Annual_Deaths.T
plt.matshow(year_matrix, interpolation=None, aspect='auto', cmap=plt.cm.Spectral_r)
plt.show()

# %%
rolmean = MonthlyDeathsDF.number.rolling(window = 8, center = False).mean()
rolstd = MonthlyDeathsDF.number.rolling(window = 8, center = False).std()

# %%
fig = plt.figure(figsize=(12,7))
orig = plt.plot(MonthlyDeathsDF.number, color='blue',label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

#Showing how DataSet is not Stationary over Time since the Mean, Variance, and Covariance are not a function of time 
#But should still test

# %%
Annual_Deaths.plot(figsize = (20,6))
plt.show()

# %%
#Thinking about cutting down years, may need to focus/ narrow in my analyzation

# %%
# Using the Dickey-Fuller Test for Stationarity 
from statsmodels.tsa.stattools import adfuller
ts = MonthlyDeathsDF.number
dftest = adfuller(ts)

# Extract and display test results in a user friendly manner
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dftest)
# Out:
# (-0.9929252939901573, 0.7558358836943408, 12, 287, {'1%': -3.453342167806272, '5%': -2.871663828287282, '10%': -2.572164381381345}, 3659.7159247152376)

# %%
print('Results of Dickey-Fuller Test:')
print(dfoutput)
#Proving that Dataset for Monthly Deaths over the Years is NonStationary
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.992925
# p-value                          0.755836
# #Lags Used                      12.000000
# Number of Observations Used    287.000000
# Critical Value (1%)             -3.453342
# Critical Value (5%)             -2.871664
# Critical Value (10%)            -2.572164
# dtype: float64

# %%
fig = plt.figure(figsize=(12,6))
plt.plot(MonthlyDeathsDF.number, color="blue")
plt.xlabel("month", fontsize=14)
plt.ylabel("Original Monthly Deaths)", fontsize=14)
plt.show()
#Original Monthly

# %%
#LoggedDeaths
LogMSdeaths = np.log(MonthlyDeathsDF.number)
LogMSdeaths = LogMSdeaths.replace([np.inf, -np.inf], np.nan)
LogMSdeaths.dropna(inplace=True)
LogMSdeathsdf = pd.DataFrame(LogMSdeaths)
fig = plt.figure(figsize=(12,6))
plt.plot(LogMSdeaths, color="blue")
plt.xlabel("month", fontsize=14)
plt.ylabel("log(Monthly Deaths)", fontsize=14)
plt.show()
#Log Transformation to help with nonstationarity dataset my making it more linear, without NaNs since dropped

# %%
#SqrtDeaths
SqrtMSdeaths = np.sqrt(MonthlyDeathsDF.number)
SqrtMSdeaths.dropna(inplace=True)
SqrtMSdeathsdf = pd.DataFrame(SqrtMSdeaths)
fig = plt.figure(figsize=(11,7))
plt.plot(SqrtMSdeaths, color="blue")
plt.xlabel("month", fontsize=14)
plt.ylabel("sqrt(monthly deaths)", fontsize=14)
plt.show()
#Checking out how SqRt does, without NaNs since dropped

# %%
#Subtracted Rolling Mean
#Can Adjust window size 
#Dropped Nans, and Plotting 
rolmean = MonthlyDeathsDF.number.rolling(window = 4).mean()
data_minus_rolmean = MonthlyDeathsDF.number - rolmean
data_minus_rolmean.dropna(inplace=True)
SubRollMeanDeathsdf = pd.DataFrame(data_minus_rolmean)
fig = plt.figure(figsize=(11,7))
plt.plot(data_minus_rolmean, color='blue',label='Deaths - rolling mean')
plt.legend(loc='best')
plt.title('Deaths while the rolling mean is subtracted')
plt.show(block=False)

# %%
#Subtracted Weighted Rolling Mean
#Avoids defining window size but must choosen assigning weights method
#Choosing Exponential decay since it proved to be more appropriate for my dataset 
#Dropped NaNs and Plotted 
exp_rolmean = MonthlyDeathsDF.number.ewm(halflife = 2).mean()
data_minus_exp_rolmean = MonthlyDeathsDF.number - exp_rolmean
data_minus_exp_rolmean.dropna(inplace=True)
SubWeightedExpRollMeanDeathsdf = pd.DataFrame(data_minus_exp_rolmean)
fig = plt.figure(figsize=(11,7))
plt.plot(data_minus_exp_rolmean, color='blue',label='Deaths - rolling mean')
plt.legend(loc='best')
plt.title('Deaths while the Exponentially Weighted rolling mean is subtracted')
plt.show(block=False)

# %%
#Differenced Deaths with 40 periods 
data_diff = MonthlyDeathsDF.diff(periods=40)
data_diff.dropna(inplace=True)
DiffDeathsdf = pd.DataFrame(data_diff)
data_diff.plot(figsize=(18,6), color='blue', linewidth=1, fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Differenced Deaths', fontsize=14);
#Using differencing up around the first spike in 1996

# %%
#Stationarity Check function for outputting Plot with rmean and rstd deviation 
from statsmodels.tsa.stattools import adfuller
def stationarity_check(TS):    
    # Calculate rolling statistics
    rolmean = TS.rolling(window = 8, center = False).mean()
    rolstd = TS.rolling(window = 8, center = False).std()
    
    # Perform the Dickey Fuller Test
    dftest = adfuller(TS['number']) 
    
    #Plot rolling statistics:
    fig = plt.figure(figsize=(12,6))
    orig = plt.plot(TS, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print ('Results of Dickey-Fuller Test:')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    
    return None

# %%
# import seasonal_decompose
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(MonthlyDeathsDF)

# Gather the trend, seasonality and noise of decomposed object
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot gathered statistics
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(np.log(ts), label='Original', color="blue")
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color="blue")
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color="blue")
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color="blue")
plt.legend(loc='best')
plt.tight_layout()

# %%
#Original Residuals Stationary Check, after statsmodels seasonal decomposition 
MonthlyDeaths_decompose = residual
MonthlyDeaths_decompose.dropna(inplace=True)
stationarity_check(MonthlyDeaths_decompose)
#After Original Decomposition, Looking at Residuals, where trend and seasonality are separated out from dataset
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.064308e+00
# p-value                        5.127576e-10
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.720000e+02
# Critical Value (1%)           -3.454622e+00
# Critical Value (5%)           -2.872225e+00
# Critical Value (10%)          -2.572464e+00
# dtype: float64

# %%
#ACF for Original
plt.figure(figsize=(12,5))
pd.plotting.autocorrelation_plot(MonthlyDeathsDF);
#seems 13 or 14 is the Highest Correlation

# %%
rcParams['figure.figsize'] = 14, 5
plot_acf(MonthlyDeaths_decompose, lags = 100);
#14 lags seems to be highest correlation

# %%
rcParams['figure.figsize'] = 14, 5
plot_pacf(MonthlyDeaths_decompose, lags = 100);
#Around 12 seems to be best
#Odd high value again around 92

# %%
#Log Decomposition
decomposition = seasonal_decompose(LogMSdeathsdf)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
# Plot gathered statistics
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(np.log(ts), label='Original', color="blue")
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color="blue")
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color="blue")
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color="blue")
plt.legend(loc='best')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-a01324d8a363> in <module>
#       1 #Log Decomposition
# ----> 2 decomposition = seasonal_decompose(LogMSdeathsdf)
#       3 trend = decomposition.trend
#       4 seasonal = decomposition.seasonal
#       5 residual = decomposition.resid
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     125             freq = pfreq
#     126         else:
# --> 127             raise ValueError("You must specify a freq or x must be a "
#     128                              "pandas object with a timeseries index with "
#     129                              "a freq not set to None")
#
# ValueError: You must specify a freq or x must be a pandas object with a timeseries index with a freq not set to None

# %%
stationarity_check(LogMSdeathsdf)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.524805
# p-value                          0.109555
# #Lags Used                       8.000000
# Number of Observations Used    290.000000
# Critical Value (1%)             -3.453102
# Critical Value (5%)             -2.871559
# Critical Value (10%)            -2.572108
# dtype: float64

# %%
#Sqrt Decomposition
decomposition = seasonal_decompose(SqrtMSdeathsdf)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
# Plot gathered statistics
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(np.log(ts), label='Original', color="blue")
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color="blue")
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color="blue")
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color="blue")
plt.legend(loc='best')
plt.tight_layout()

# %%
#Residual Check for SQRT deaths
SqrtMonthlyDeaths_decompose = residual
SqrtMonthlyDeaths_decompose.dropna(inplace=True)
stationarity_check(SqrtMonthlyDeaths_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.655310e+00
# p-value                        1.399282e-16
# #Lags Used                     1.100000e+01
# Number of Observations Used    2.760000e+02
# Critical Value (1%)           -3.454267e+00
# Critical Value (5%)           -2.872070e+00
# Critical Value (10%)          -2.572381e+00
# dtype: float64

# %%
#SubRollMean Decomposition
decomposition = seasonal_decompose(SubRollMeanDeathsdf)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
# Plot gathered statistics
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(np.log(ts), label='Original', color="blue")
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color="blue")
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color="blue")
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color="blue")
plt.legend(loc='best')
plt.tight_layout()

# %%
#Residual Check for SubRollMean deaths
SRollMonthlyDeaths_decompose = residual
SRollMonthlyDeaths_decompose.dropna(inplace=True)
stationarity_check(SRollMonthlyDeaths_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.832058e+00
# p-value                        1.758958e-14
# #Lags Used                     1.500000e+01
# Number of Observations Used    2.690000e+02
# Critical Value (1%)           -3.454896e+00
# Critical Value (5%)           -2.872345e+00
# Critical Value (10%)          -2.572528e+00
# dtype: float64

# %%
stationarity_check(SubRollMeanDeathsdf)
#Seems to outperform statsmodels residuals from decomposition, and its own 
#Most Stationary of them all
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.063956e+01
# p-value                        4.970397e-19
# #Lags Used                     1.000000e+01
# Number of Observations Used    2.860000e+02
# Critical Value (1%)           -3.453423e+00
# Critical Value (5%)           -2.871699e+00
# Critical Value (10%)          -2.572183e+00
# dtype: float64

# %%
#SubWeightedExpRollMean Decomposition
decomposition = seasonal_decompose(SubWeightedExpRollMeanDeathsdf)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
# Plot gathered statistics
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(np.log(ts), label='Original', color="blue")
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color="blue")
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color="blue")
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color="blue")
plt.legend(loc='best')
plt.tight_layout()

# %%
#Residual Check for SubWeightedExpRollMean deaths, improved itself when focusing on residuals
SWERM_MonthlyDeaths_decompose = residual
SWERM_MonthlyDeaths_decompose.dropna(inplace=True)
stationarity_check(SWERM_MonthlyDeaths_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.764254e+00
# p-value                        9.278517e-12
# #Lags Used                     1.600000e+01
# Number of Observations Used    2.710000e+02
# Critical Value (1%)           -3.454713e+00
# Critical Value (5%)           -2.872265e+00
# Critical Value (10%)          -2.572485e+00
# dtype: float64

# %%
stationarity_check(SubWeightedExpRollMeanDeathsdf)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.256707
# p-value                          0.000007
# #Lags Used                      12.000000
# Number of Observations Used    287.000000
# Critical Value (1%)             -3.453342
# Critical Value (5%)             -2.871664
# Critical Value (10%)            -2.572164
# dtype: float64

# %%
#Searching for best Detrended ACF and PACF

# %%
rcParams['figure.figsize'] = 14, 5
plot_acf(MonthlyDeaths_decompose, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_pacf(MonthlyDeaths_decompose, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_acf(SubRollMeanDeathsdf, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_pacf(SubRollMeanDeathsdf, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_acf(SRollMonthlyDeaths_decompose, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_pacf(SRollMonthlyDeaths_decompose, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_acf(SqrtMSdeathsdf, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_pacf(SqrtMSdeathsdf, lags = 100);

# %%
#DiffDeaths from the first 40 periods in dataset 
rcParams['figure.figsize'] = 14, 5
plot_acf(DiffDeathsdf, lags = 100);

# %%
rcParams['figure.figsize'] = 14, 5
plot_pacf(DiffDeathsdf, lags = 100);

# %%
# Fit an ARMA(13,1) model to the DiffDeathsdf data
mod_arma = ARMA(MonthlyDeathsDF, order=(12,5))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())

# Print out the estimate for the constant and for theta
print(res_arma.params)
#Possibly the best performer
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                 number   No. Observations:                  300
# Model:                    ARMA(12, 5)   Log Likelihood               -1914.672
# Method:                       css-mle   S.D. of innovations            142.090
# Date:                Wed, 24 Jul 2019   AIC                           3867.345
# Time:                        10:05:22   BIC                           3937.716
# Sample:                    01-01-1993   HQIC                          3895.507
#                          - 12-01-2017
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           118.2979     47.600      2.485      0.014      25.004     211.592
# ar.L1.number      1.2731      0.235      5.410      0.000       0.812       1.734
# ar.L2.number     -0.8891      0.437     -2.035      0.043      -1.745      -0.033
# ar.L3.number     -0.1945      0.537     -0.362      0.718      -1.247       0.858
# ar.L4.number      0.9704      0.401      2.421      0.016       0.185       1.756
# ar.L5.number     -1.0283      0.184     -5.600      0.000      -1.388      -0.668
# ar.L6.number      0.3479      0.168      2.072      0.039       0.019       0.677
# ar.L7.number      0.1963      0.198      0.992      0.322      -0.192       0.584
# ar.L8.number     -0.3140      0.131     -2.394      0.017      -0.571      -0.057
# ar.L9.number      0.4161      0.116      3.597      0.000       0.189       0.643
# ar.L10.number    -0.1818      0.175     -1.036      0.301      -0.526       0.162
# ar.L11.number     0.0974      0.163      0.599      0.550      -0.221       0.416
# ar.L12.number     0.1790      0.114      1.574      0.117      -0.044       0.402
# ma.L1.number     -1.0774      0.227     -4.755      0.000      -1.522      -0.633
# ma.L2.number      0.7257      0.382      1.898      0.059      -0.024       1.475
# ma.L3.number      0.2353      0.467      0.503      0.615      -0.681       1.151
# ma.L4.number     -0.7180      0.342     -2.099      0.037      -1.388      -0.047
# ma.L5.number      0.6451      0.163      3.948      0.000       0.325       0.965
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.0294           -0.0000j            1.0294           -0.0000
# AR.2             0.8587           -0.5506j            1.0201           -0.0907
# AR.3             0.8587           +0.5506j            1.0201            0.0907
# AR.4             0.6295           -0.9257j            1.1194           -0.1549
# AR.5             0.6295           +0.9257j            1.1194            0.1549
# AR.6             0.1550           -1.0052j            1.0171           -0.2256
# AR.7             0.1550           +1.0052j            1.0171            0.2256
# AR.8            -0.3579           -1.2018j            1.2540           -0.2961
# AR.9            -0.3579           +1.2018j            1.2540            0.2961
# AR.10           -1.1417           -0.2677j            1.1726           -0.4633
# AR.11           -1.1417           +0.2677j            1.1726            0.4633
# AR.12           -1.8608           -0.0000j            1.8608           -0.5000
# MA.1            -1.1830           -0.0000j            1.1830           -0.5000
# MA.2             0.2093           -1.0124j            1.0338           -0.2175
# MA.3             0.2093           +1.0124j            1.0338            0.2175
# MA.4             0.9386           -0.5875j            1.1073           -0.0890
# MA.5             0.9386           +0.5875j            1.1073            0.0890
# ------------------------------------------------------------------------------
# const            118.297854
# ar.L1.number       1.273115
# ar.L2.number      -0.889072
# ar.L3.number      -0.194504
# ar.L4.number       0.970406
# ar.L5.number      -1.028251
# ar.L6.number       0.347852
# ar.L7.number       0.196291
# ar.L8.number      -0.314038
# ar.L9.number       0.416070
# ar.L10.number     -0.181820
# ar.L11.number      0.097377
# ar.L12.number      0.178982
# ma.L1.number      -1.077445
# ma.L2.number       0.725716
# ma.L3.number       0.235301
# ma.L4.number      -0.717956
# ma.L5.number       0.645140
# dtype: float64

# %%
# Fit an ARMA(3,3) model to the SqrtMonthlyDeaths_decompose data
mod_arma = ARMA(SqrtMonthlyDeaths_decompose, order=(3,4))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())

# Print out the estimate for the constant and for theta
print(res_arma.params)
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                 number   No. Observations:                  288
# Model:                     ARMA(3, 4)   Log Likelihood                -798.255
# Method:                       css-mle   S.D. of innovations              3.817
# Date:                Tue, 23 Jul 2019   AIC                           1614.510
# Time:                        15:23:05   BIC                           1647.477
# Sample:                    07-01-1993   HQIC                          1627.721
#                          - 06-01-2017
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.0005      0.003     -0.170      0.865      -0.007       0.006
# ar.L1.number     0.3999      0.073      5.493      0.000       0.257       0.543
# ar.L2.number     0.6576      0.059     11.170      0.000       0.542       0.773
# ar.L3.number    -0.6865      0.058    -11.795      0.000      -0.801      -0.572
# ma.L1.number    -0.6842      0.096     -7.123      0.000      -0.872      -0.496
# ma.L2.number    -0.9559      0.096     -9.926      0.000      -1.145      -0.767
# ma.L3.number     0.6841      0.095      7.195      0.000       0.498       0.870
# ma.L4.number    -0.0440      0.093     -0.476      0.635      -0.225       0.137
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0185           -0.0000j            1.0185           -0.5000
# AR.2            0.9882           -0.6736j            1.1959           -0.0952
# AR.3            0.9882           +0.6736j            1.1959            0.0952
# MA.1           -1.0001           +0.0000j            1.0001            0.5000
# MA.2            1.0000           +0.0000j            1.0000            0.0000
# MA.3            1.6336           +0.0000j            1.6336            0.0000
# MA.4           13.9004           +0.0000j           13.9004            0.0000
# -----------------------------------------------------------------------------
# const          -0.000533
# ar.L1.number    0.399923
# ar.L2.number    0.657556
# ar.L3.number   -0.686474
# ma.L1.number   -0.684166
# ma.L2.number   -0.955856
# ma.L3.number    0.684059
# ma.L4.number   -0.044037
# dtype: float64

# %%
# Fit an ARMA(3,3) model to the SRollMonthlyDeaths_decompose data
mod_arma = ARMA(SRollMonthlyDeaths_decompose, order=(3,1))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())

# Print out the estimate for the constant and for theta
print(res_arma.params)
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                 number   No. Observations:                  285
# Model:                     ARMA(3, 1)   Log Likelihood               -1732.101
# Method:                       css-mle   S.D. of innovations            104.307
# Date:                Tue, 23 Jul 2019   AIC                           3476.203
# Time:                        15:23:05   BIC                           3498.118
# Sample:                    10-01-1993   HQIC                          3484.988
#                          - 06-01-2017
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0270      0.086      0.313      0.754      -0.142       0.196
# ar.L1.number     0.6351      0.057     11.146      0.000       0.523       0.747
# ar.L2.number    -0.2168      0.067     -3.240      0.001      -0.348      -0.086
# ar.L3.number    -0.2943      0.057     -5.145      0.000      -0.406      -0.182
# ma.L1.number    -1.0000      0.009   -112.341      0.000      -1.017      -0.983
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.7860           -0.9240j            1.2131           -0.1378
# AR.2            0.7860           +0.9240j            1.2131            0.1378
# AR.3           -2.3087           -0.0000j            2.3087           -0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# const           0.026966
# ar.L1.number    0.635112
# ar.L2.number   -0.216837
# ar.L3.number   -0.294347
# ma.L1.number   -1.000000
# dtype: float64

# %%
# Fit an ARMA(3,1) model to the SubRollMeanDeathsdf data
mod_arma = ARMA(SubRollMeanDeathsdf, order=(13,3))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())

# Print out the estimate for the constant and for theta
print(res_arma.params)
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                 number   No. Observations:                  297
# Model:                    ARMA(13, 3)   Log Likelihood               -1814.165
# Method:                       css-mle   S.D. of innovations            108.271
# Date:                Tue, 23 Jul 2019   AIC                           3664.329
# Time:                        15:23:45   BIC                           3730.817
# Sample:                    04-01-1993   HQIC                          3690.947
#                          - 12-01-2017
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =3582.9661950763984
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =3941.2476327212653
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =3788.4656013670997
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =3867.8656985171724
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =3616.0456612313096
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =3783.945196181586
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =3766.0254936233778
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =3657.1077622410517
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =3617.9564721999304
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =3875.630512847748
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =3726.5097310591323
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =3858.1073414938237
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =3594.6702084725275
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =3735.6562856924097
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =3728.2597647885596
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =3659.0757363591974
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =3596.3339833423533
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =3957.3570510646164
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =3807.295831710855
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =3959.691434996399
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =3677.7829442718003
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =3807.2446847358196
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =3809.1823236467285
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =3743.9135861267523
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =3679.454821680324
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =3853.65237220323
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =3707.3730605437377
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =3848.3374319957406
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =3578.6461346323786
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =3719.1026440020637
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =3709.1163998096226
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =3648.9994261182364
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =3580.559059148145

# %%
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (0, 1, 1, 12)
# aic           3578.65
# Name: 59, dtype: object

# %%
#Using the 12,5 for p,q since what seemed to be best ACF PACF values from prior search for ARMA
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(MonthlyDeathsDF,
                                order=(12, 1, 5),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9553      1.675     -0.570      0.569      -4.239       2.328
# ar.L2         -0.7669      0.692     -1.108      0.268      -2.124       0.590
# ar.L3         -1.0780      0.892     -1.208      0.227      -2.827       0.671
# ar.L4         -0.2614      1.354     -0.193      0.847      -2.915       2.393
# ar.L5          0.0388      0.387      0.100      0.920      -0.720       0.798
# ar.L6         -0.0531      0.256     -0.207      0.836      -0.555       0.449
# ar.L7          0.1934      0.231      0.838      0.402      -0.259       0.646
# ar.L8          0.1602      0.406      0.395      0.693      -0.635       0.956
# ar.L9          0.2837      0.219      1.298      0.194      -0.145       0.712
# ar.L10         0.2603      0.519      0.501      0.616      -0.758       1.278
# ar.L11         0.0598      0.290      0.206      0.837      -0.510       0.629
# ar.L12        -0.0435      0.137     -0.318      0.750      -0.312       0.224
# ma.L1          0.1226      1.672      0.073      0.942      -3.155       3.400
# ma.L2         -0.0842      0.706     -0.119      0.905      -1.467       1.299
# ma.L3          0.2957      0.252      1.173      0.241      -0.199       0.790
# ma.L4         -0.7192      0.454     -1.583      0.113      -1.610       0.171
# ma.L5         -0.4874      1.488     -0.328      0.743      -3.403       2.428
# ma.S.L12      -0.7683      0.104     -7.406      0.000      -0.972      -0.565
# sigma2      3.265e+04   3273.029      9.976      0.000    2.62e+04    3.91e+04
# ==============================================================================

# %%
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %%
pred = output.get_prediction(start=pd.to_datetime('2015-01-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = MonthlyDeathsDF['1996':].plot(label='observed')

#Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=.5)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Deaths')
plt.legend()

plt.show()

#Predictions MonthlyDeathsDF with SARIMA

# %%
# Get the Real and predicted values
Deaths_forecasted = pred.predicted_mean
Deaths_truth = MonthlyDeathsDF['2015-01-01':]

# Compute the mean square error
mse = ((Deaths_forecasted - Deaths_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 2015-01-01 00:00:00   NaN
# 2015-02-01 00:00:00   NaN
# 2015-03-01 00:00:00   NaN
# 2015-04-01 00:00:00   NaN
# 2015-05-01 00:00:00   NaN
# 2015-06-01 00:00:00   NaN
# 2015-07-01 00:00:00   NaN
# 2015-08-01 00:00:00   NaN
# 2015-09-01 00:00:00   NaN
# 2015-10-01 00:00:00   NaN
# 2015-11-01 00:00:00   NaN
# 2015-12-01 00:00:00   NaN
# 2016-01-01 00:00:00   NaN
# 2016-02-01 00:00:00   NaN
# 2016-03-01 00:00:00   NaN
# 2016-04-01 00:00:00   NaN
# 2016-05-01 00:00:00   NaN
# 2016-06-01 00:00:00   NaN
# 2016-07-01 00:00:00   NaN
# 2016-08-01 00:00:00   NaN
# 2016-09-01 00:00:00   NaN
# 2016-10-01 00:00:00   NaN
# 2016-11-01 00:00:00   NaN
# 2016-12-01 00:00:00   NaN
# 2017-01-01 00:00:00   NaN
# 2017-02-01 00:00:00   NaN
# 2017-03-01 00:00:00   NaN
# 2017-04-01 00:00:00   NaN
# 2017-05-01 00:00:00   NaN
# 2017-06-01 00:00:00   NaN
# 2017-07-01 00:00:00   NaN
# 2017-08-01 00:00:00   NaN
# 2017-09-01 00:00:00   NaN
# 2017-10-01 00:00:00   NaN
# 2017-11-01 00:00:00   NaN
# 2017-12-01 00:00:00   NaN
# number                NaN
# dtype: float64

# %%
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(SubRollMeanDeathsdf,
                                order=(1, 0, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6277      0.039     15.902      0.000       0.550       0.705
# ma.L1         -0.9661      0.015    -64.833      0.000      -0.995      -0.937
# ma.S.L12      -0.8445      0.034    -24.986      0.000      -0.911      -0.778
# sigma2      1.749e+04    593.722     29.451      0.000    1.63e+04    1.86e+04
# ==============================================================================

# %%
pred = output.get_prediction(start=pd.to_datetime('2015-01-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
#SubRollMeanDeathsdf Predictions
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = SubRollMeanDeathsdf['1996':].plot(label='observed')

#Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=.5)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Deaths')
plt.legend()

plt.show()

# %%
# Get the Real and predicted values
Deaths_forecasted = pred.predicted_mean
Deaths_truth = SubRollMeanDeathsdf['2015-01-01':]

# Compute the mean square error
mse = ((Deaths_forecasted - Deaths_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 2015-01-01 00:00:00   NaN
# 2015-02-01 00:00:00   NaN
# 2015-03-01 00:00:00   NaN
# 2015-04-01 00:00:00   NaN
# 2015-05-01 00:00:00   NaN
# 2015-06-01 00:00:00   NaN
# 2015-07-01 00:00:00   NaN
# 2015-08-01 00:00:00   NaN
# 2015-09-01 00:00:00   NaN
# 2015-10-01 00:00:00   NaN
# 2015-11-01 00:00:00   NaN
# 2015-12-01 00:00:00   NaN
# 2016-01-01 00:00:00   NaN
# 2016-02-01 00:00:00   NaN
# 2016-03-01 00:00:00   NaN
# 2016-04-01 00:00:00   NaN
# 2016-05-01 00:00:00   NaN
# 2016-06-01 00:00:00   NaN
# 2016-07-01 00:00:00   NaN
# 2016-08-01 00:00:00   NaN
# 2016-09-01 00:00:00   NaN
# 2016-10-01 00:00:00   NaN
# 2016-11-01 00:00:00   NaN
# 2016-12-01 00:00:00   NaN
# 2017-01-01 00:00:00   NaN
# 2017-02-01 00:00:00   NaN
# 2017-03-01 00:00:00   NaN
# 2017-04-01 00:00:00   NaN
# 2017-05-01 00:00:00   NaN
# 2017-06-01 00:00:00   NaN
# 2017-07-01 00:00:00   NaN
# 2017-08-01 00:00:00   NaN
# 2017-09-01 00:00:00   NaN
# 2017-10-01 00:00:00   NaN
# 2017-11-01 00:00:00   NaN
# 2017-12-01 00:00:00   NaN
# number                NaN
# dtype: float64

# %%
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(SqrtMSdeathsdf,
                                order=(1, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1501      0.053      2.809      0.005       0.045       0.255
# ma.L1         -0.9268      0.021    -45.138      0.000      -0.967      -0.887
# ma.S.L12      -0.9084      0.043    -21.272      0.000      -0.992      -0.825
# sigma2        28.0152      1.478     18.949      0.000      25.117      30.913
# ==============================================================================

# %%
pred = output.get_prediction(start=pd.to_datetime('2015-01-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
#SqrtMSdeathsdf Predictions


rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = SqrtMSdeathsdf['1996':].plot(label='observed')

#Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=.5)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Deaths')
plt.legend()

plt.show()

# %%
Deaths_forecasted = pred.predicted_mean
Deaths_truth = SqrtMSdeathsdf['2015-01-01':]

# Compute the mean square error
mse = ((Deaths_forecasted - Deaths_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 2015-01-01 00:00:00   NaN
# 2015-02-01 00:00:00   NaN
# 2015-03-01 00:00:00   NaN
# 2015-04-01 00:00:00   NaN
# 2015-05-01 00:00:00   NaN
# 2015-06-01 00:00:00   NaN
# 2015-07-01 00:00:00   NaN
# 2015-08-01 00:00:00   NaN
# 2015-09-01 00:00:00   NaN
# 2015-10-01 00:00:00   NaN
# 2015-11-01 00:00:00   NaN
# 2015-12-01 00:00:00   NaN
# 2016-01-01 00:00:00   NaN
# 2016-02-01 00:00:00   NaN
# 2016-03-01 00:00:00   NaN
# 2016-04-01 00:00:00   NaN
# 2016-05-01 00:00:00   NaN
# 2016-06-01 00:00:00   NaN
# 2016-07-01 00:00:00   NaN
# 2016-08-01 00:00:00   NaN
# 2016-09-01 00:00:00   NaN
# 2016-10-01 00:00:00   NaN
# 2016-11-01 00:00:00   NaN
# 2016-12-01 00:00:00   NaN
# 2017-01-01 00:00:00   NaN
# 2017-02-01 00:00:00   NaN
# 2017-03-01 00:00:00   NaN
# 2017-04-01 00:00:00   NaN
# 2017-05-01 00:00:00   NaN
# 2017-06-01 00:00:00   NaN
# 2017-07-01 00:00:00   NaN
# 2017-08-01 00:00:00   NaN
# 2017-09-01 00:00:00   NaN
# 2017-10-01 00:00:00   NaN
# 2017-11-01 00:00:00   NaN
# 2017-12-01 00:00:00   NaN
# number                NaN
# dtype: float64

# %%
pred

# %%
dir(pred.prediction_results)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_attributes',
#  '_endog',
#  '_filter_attributes',
#  '_filter_options',
#  '_forecasts',
#  '_forecasts_error_cov',
#  '_model_attributes',
#  '_predict',
#  'end',
#  'filter_attributes',
#  'kalman_gain',
#  'ndynamic',
#  'nforecast',
#  'npredictions',
#  'nstatic',
#  'predict',
#  'representation_attributes',
#  'results',
#  'standardized_forecasts_error',
#  'start',
#  'update_filter',
#  'update_representation']

# %%
dir(pred.prediction_results.results)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_attributes',
#  '_compatibility_mode',
#  '_filter_attributes',
#  '_filter_options',
#  '_get_smoothed_forecasts',
#  '_kalman_gain',
#  '_model_attributes',
#  '_predict',
#  '_smoothed_forecasts',
#  '_smoothed_forecasts_error',
#  '_smoothed_forecasts_error_cov',
#  '_smoother_attributes',
#  '_smoother_options',
#  '_standardized_forecasts_error',
#  'collapsed_forecasts',
#  'collapsed_forecasts_error',
#  'collapsed_forecasts_error_cov',
#  'conserve_memory',
#  'converged',
#  'design',
#  'dtype',
#  'endog',
#  'filter_augmented',
#  'filter_collapsed',
#  'filter_conventional',
#  'filter_exact_initial',
#  'filter_extended',
#  'filter_method',
#  'filter_square_root',
#  'filter_timing',
#  'filter_univariate',
#  'filter_unscented',
#  'filtered_state',
#  'filtered_state_cov',
#  'forecasts',
#  'forecasts_error',
#  'forecasts_error_cov',
#  'initial_state',
#  'initial_state_cov',
#  'initial_variance',
#  'initialization',
#  'inversion_method',
#  'invert_cholesky',
#  'invert_lu',
#  'invert_univariate',
#  'k_endog',
#  'k_posdef',
#  'k_states',
#  'kalman_gain',
#  'llf_obs',
#  'loglikelihood_burn',
#  'memory_conserve',
#  'memory_no_filtered',
#  'memory_no_forecast',
#  'memory_no_gain',
#  'memory_no_likelihood',
#  'memory_no_predicted',
#  'memory_no_smoothing',
#  'memory_no_std_forecast',
#  'memory_store_all',
#  'missing',
#  'missing_forecasts',
#  'missing_forecasts_error',
#  'missing_forecasts_error_cov',
#  'model',
#  'nmissing',
#  'nobs',
#  'obs_cov',
#  'obs_intercept',
#  'period_converged',
#  'predict',
#  'predicted_state',
#  'predicted_state_cov',
#  'prefix',
#  'scaled_smoothed_estimator',
#  'scaled_smoothed_estimator_cov',
#  'selection',
#  'shapes',
#  'smoothed_forecasts',
#  'smoothed_forecasts_error',
#  'smoothed_forecasts_error_cov',
#  'smoothed_measurement_disturbance',
#  'smoothed_measurement_disturbance_cov',
#  'smoothed_state',
#  'smoothed_state_autocov',
#  'smoothed_state_cov',
#  'smoothed_state_disturbance',
#  'smoothed_state_disturbance_cov',
#  'smoother_all',
#  'smoother_disturbance',
#  'smoother_disturbance_cov',
#  'smoother_output',
#  'smoother_state',
#  'smoother_state_autocov',
#  'smoother_state_cov',
#  'smoothing_error',
#  'solve_cholesky',
#  'solve_lu',
#  'stability_force_symmetry',
#  'stability_method',
#  'standardized_forecasts_error',
#  'state_cov',
#  'state_intercept',
#  'time_invariant',
#  'tmp1',
#  'tmp2',
#  'tmp3',
#  'tmp4',
#  'tolerance',
#  'transition',
#  'update_filter',
#  'update_representation',
#  'update_smoother']
